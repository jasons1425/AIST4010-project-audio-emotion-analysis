# %% [markdown]
# ## environment setup

# %%
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy import SpotifyException
from IPython.display import clear_output
import pandas as pd
import numpy as np
import requests
import spotipy
import os

# %%
DATA_PATH = r"D:\Documents\datasets\AIST4010\muse\muse_v3.csv"
DATA_STORE = r"D:\Documents\datasets\AIST4010\muse\songs"
VALID_DATA_PATH = r"D:\Documents\datasets\AIST4010\muse\valid_data.csv"
# client ID for fetching spotify preview URL
SPOTIFY_CLIENT_ID = r""
# client secret for fetching spotify preview URL
SPOTIFY_CLIENT_SECRET = r""
# OAUTH_TOKEN for making queries to spotify API endpoints directly
OAUTH_TOKEN = r""
client_credentials_manager = SpotifyClientCredentials(client_id=SPOTIFY_CLIENT_ID, client_secret=SPOTIFY_CLIENT_SECRET)

# %% [markdown]
# ## data preparation

# %%
data_types = {'valence_tags': np.float32, 'arousal_tags':np.float32, 'dominance_tags':np.float32}
data = pd.read_csv(DATA_PATH, dtype=data_types)
data.set_index('spotify_id', inplace=True)

data.head()
# Out:
#                                                                lastfm_url  \
# spotify_id
# 4xkOaSrkexMciUUogZKVTS  https://www.last.fm/music/eminem/_/%2527till%2...
# 3fOc9x06lKJBhz435mInlH  https://www.last.fm/music/metallica/_/st.%2banger
# 3Y96xd4Ce0J47dcalLrEC8  https://www.last.fm/music/rick%2bross/_/speedi...
# 6tqFC1DIOphJkCwrjVzPmg  https://www.last.fm/music/m.i.a./_/bamboo%2bbanga
# 5bU4KX47KqtDKKaLM4QCzh    https://www.last.fm/music/dope/_/die%2bmf%2bdie
#
#                                    track     artist  \
# spotify_id
# 4xkOaSrkexMciUUogZKVTS  'Till I Collapse     Eminem
# 3fOc9x06lKJBhz435mInlH         St. Anger  Metallica
# 3Y96xd4Ce0J47dcalLrEC8          Speedin'  Rick Ross
# 6tqFC1DIOphJkCwrjVzPmg      Bamboo Banga     M.I.A.
# 5bU4KX47KqtDKKaLM4QCzh        Die MF Die       Dope
#
#                                                              seeds  \
# spotify_id
# 4xkOaSrkexMciUUogZKVTS                              ['aggressive']
# 3fOc9x06lKJBhz435mInlH                              ['aggressive']
# 3Y96xd4Ce0J47dcalLrEC8                              ['aggressive']
# 6tqFC1DIOphJkCwrjVzPmg  ['aggressive', 'fun', 'sexy', 'energetic']
# 5bU4KX47KqtDKKaLM4QCzh                              ['aggressive']
#
#                         number_of_emotion_tags  valence_tags  arousal_tags  \
# spotify_id
# 4xkOaSrkexMciUUogZKVTS                       6      4.550000      5.273125
# 3fOc9x06lKJBhz435mInlH                       8      3.710000      5.833000
# 3Y96xd4Ce0J47dcalLrEC8                       1      3.080000      5.870000
# 6tqFC1DIOphJkCwrjVzPmg                      13      6.555071      5.537214
# 5bU4KX47KqtDKKaLM4QCzh                       7      3.771177      5.348235
#
#                         dominance_tags                                  mbid  \
# spotify_id
# 4xkOaSrkexMciUUogZKVTS        5.690625  cab93def-26c5-4fb0-bedd-26ec4c1619e1
# 3fOc9x06lKJBhz435mInlH        5.427250  727a2529-7ee8-4860-aef6-7959884895cb
# 3Y96xd4Ce0J47dcalLrEC8        5.490000                                   NaN
# 6tqFC1DIOphJkCwrjVzPmg        5.691357  99dd2c8c-e7c1-413e-8ea4-4497a00ffa18
# 5bU4KX47KqtDKKaLM4QCzh        5.441765  b9eb3484-5e0e-4690-ab5a-ca91937032a5
#
#                           genre
# spotify_id
# 4xkOaSrkexMciUUogZKVTS      rap
# 3fOc9x06lKJBhz435mInlH    metal
# 3Y96xd4Ce0J47dcalLrEC8      rap
# 6tqFC1DIOphJkCwrjVzPmg  hip-hop
# 5bU4KX47KqtDKKaLM4QCzh    metal

# %%
# data filtering

data = data.loc[data.index.notna()]  # remove the entries that have no spotify id
data = data.loc[~data.index.duplicated()]  # remove the duplicated entries
data.track = data.track + ' - ' + data.artist  # combine the track column with the artist name
del data['artist']  # remove artist as this info is already added to the track attribute
print(len(data))
# Out:
# 60656

# %% [markdown]
# ## fetch data

# %%
# through spotipy module
# ALERT: may have max retries error after fetching for a while
# fetch api setup
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
spotify.max_retries=10
spotify.backoff_factor = 0.4
spotify.retries = 10

# fetching
track_ids = data.index
ttl_track = len(track_ids)
valid_track = [False] * ttl_track

for base in range(0, ttl_track, 50):
    track_queries = track_ids[base:min(base+50, ttl_track)]
    tracks = spotify.tracks(track_queries)
    high_lv_features = spotify.audio_features(track_queries)
    for idx, track_id in enumerate(track_queries):
        track = tracks[idx]
        track_feature = high_lv_features[idx]
        preview_url = track.get("preview_url", None)
        speechiness = track_feature.get("speechiness", None)
        if preview_url and speechiness <= 0.6:  # also filter out songs that consists of too many words
            valid_track[base + idx] = True
            song_preview = requests.get(preview_url)
            with open(os.path.join(DATA_STORE, f'{track_id}.mp3'), 'wb') as f:
                f.write(song_preview.content)
    clear_output(wait=True)
    ttl_valid = sum(valid_track)
    print(f"{ttl_valid:<6} / {len(track_ids):<6} - {idx + 1 - ttl_valid} invalid")

valid_data = data.loc[valid_track]  # data with preview url
valid_data.to_csv(VALID_DATA_PATH)

# %%
# through direct API endpoint query after getting oauth token from Spotify API website
# ALERT: the token may expire after a while (~an hour)
header = {"Accept":"application/json",
          "Authorization":"Bearer "+ OAUTH_TOKEN,  # define OAUTH_TOKEN in environment
          "Content-Type":"application/json"}

def fetch_tracks(track_ids):
    response = requests.get(r"https://api.spotify.com/v1/tracks?ids="+"%2C".join(track_ids), headers=header)
    if response.status_code != 200:
        print(f"Fail to fetch tracks {track_ids[0]} ... {track_ids[-1]}.")
        print(f"{track_data.json()}")
        return None
    return response.json()['tracks']


def fetch_features(track_ids):
    response = requests.get(r"	https://api.spotify.com/v1/audio-features?ids="+"%2C".join(track_ids), headers=header)
    if response.status_code != 200:
        print(f"Fail to fetch tracks {track_ids[0]} ... {track_ids[-1]}.")
        print(f"{track_data.json()}")
        return None
    return response.json()['audio_features']
    

# fetching
track_ids = data.index
ttl_track = len(track_ids)
valid_track = [False] * ttl_track

for base in range(0, ttl_track, 50):
    track_queries = track_ids[base:min(base+50, ttl_track)]
    tracks = fetch_tracks(track_queries)
    high_lv_features = fetch_features(track_queries)
    for idx, track_id in enumerate(track_queries):
        track = tracks[idx]
        track_feature = high_lv_features[idx]
        if track is None or track_feature is None: continue
        preview_url = track.get("preview_url", None)
        speechiness = track_feature.get("speechiness", None)
        if preview_url and speechiness <= 0.6:  # also filter out songs that consists of too many words
            valid_track[base + idx] = True
            song_preview = requests.get(preview_url)
            with open(os.path.join(DATA_STORE, f'{track_id}.mp3'), 'wb') as f:
                f.write(song_preview.content)
    clear_output(wait=True)
    ttl_valid = sum(valid_track)
    print(f"{ttl_valid:<6} / {len(track_ids):<6} - {base + len(track_queries) + 1 - ttl_valid} invalid")

# valid_data = data.loc[valid_track]  # data with preview url
# valid_data.to_csv(VALID_DATA_PATH)

# %% [markdown]
# ## Import the valid data

# %%
track_data = pd.read_csv(VALID_DATA_PATH)
track_data.set_index("spotify_id", inplace=True)

print(track_data.shape)
track_data.head()
# Out:
# (39971, 9)
#                                                                lastfm_url  \
# spotify_id
# 3fOc9x06lKJBhz435mInlH  https://www.last.fm/music/metallica/_/st.%2banger
# 5bU4KX47KqtDKKaLM4QCzh    https://www.last.fm/music/dope/_/die%2bmf%2bdie
# 6DoXuH326aAYEN8CnlLmhP     https://www.last.fm/music/deftones/_/7%2bwords
# 104YdibC7VQy78xAVmgRYr     https://www.last.fm/music/fiona%2bapple/_/limp
# 5fU6qjmD38P90BMsuqpiuU  https://www.last.fm/music/metallica/_/sweet%2b...
#
#                                           track  \
# spotify_id
# 3fOc9x06lKJBhz435mInlH    St. Anger - Metallica
# 5bU4KX47KqtDKKaLM4QCzh        Die MF Die - Dope
# 6DoXuH326aAYEN8CnlLmhP       7 Words - Deftones
# 104YdibC7VQy78xAVmgRYr       Limp - Fiona Apple
# 5fU6qjmD38P90BMsuqpiuU  Sweet Amber - Metallica
#
#                                                     seeds  \
# spotify_id
# 3fOc9x06lKJBhz435mInlH                     ['aggressive']
# 5bU4KX47KqtDKKaLM4QCzh                     ['aggressive']
# 6DoXuH326aAYEN8CnlLmhP            ['aggressive', 'angry']
# 104YdibC7VQy78xAVmgRYr  ['aggressive', 'angry', 'bitter']
# 5fU6qjmD38P90BMsuqpiuU                     ['aggressive']
#
#                         number_of_emotion_tags  valence_tags  arousal_tags  \
# spotify_id
# 3fOc9x06lKJBhz435mInlH                       8      3.710000      5.833000
# 5bU4KX47KqtDKKaLM4QCzh                       7      3.771177      5.348235
# 6DoXuH326aAYEN8CnlLmhP                      10      3.807121      5.473939
# 104YdibC7VQy78xAVmgRYr                      20      3.737211      5.610204
# 5fU6qjmD38P90BMsuqpiuU                       4      3.582759      5.757241
#
#                         dominance_tags                                  mbid  \
# spotify_id
# 3fOc9x06lKJBhz435mInlH        5.427250  727a2529-7ee8-4860-aef6-7959884895cb
# 5bU4KX47KqtDKKaLM4QCzh        5.441765  b9eb3484-5e0e-4690-ab5a-ca91937032a5
# 6DoXuH326aAYEN8CnlLmhP        4.729091  1a826083-5585-445f-a708-415dc90aa050
# 104YdibC7VQy78xAVmgRYr        4.626735  4435982c-b83e-4daa-af2b-9f3430036bb7
# 5fU6qjmD38P90BMsuqpiuU        5.340000  fe1cc051-faa7-4953-b331-f6196cd3ddae
#
#                                     genre
# spotify_id
# 3fOc9x06lKJBhz435mInlH              metal
# 5bU4KX47KqtDKKaLM4QCzh              metal
# 6DoXuH326aAYEN8CnlLmhP           nu metal
# 104YdibC7VQy78xAVmgRYr  singer-songwriter
# 5fU6qjmD38P90BMsuqpiuU              metal

# %%
genre_cnt = track_data.genre.value_counts()
for idx in genre_cnt.index:
    print(f"{idx:<20} - {genre_cnt[idx]}")
# Out:
# indie                - 3096
# rock                 - 2851
# electronic           - 2516
# pop                  - 2214
# folk                 - 1325
# ambient              - 1273
# alternative          - 988
# soundtrack           - 813
# hip-hop              - 783
# soul                 - 719
# jazz                 - 615
# singer-songwriter    - 614
# experimental         - 593
# industrial           - 542
# piano                - 533
# acoustic             - 521
# indie rock           - 421
# alternative rock     - 404
# punk                 - 402
# classic rock         - 376
# new age              - 373
# metal                - 356
# progressive rock     - 351
# classical            - 341
# trip-hop             - 337
# dance                - 336
# electronica          - 316
# indie pop            - 294
# post-rock            - 284
# trance               - 282
# hard rock            - 279
# downtempo            - 257
# country              - 249
# new wave             - 232
# chill                - 227
# hip hop              - 224
# post-punk            - 216
# noise                - 202
# blues                - 201
# lounge               - 197
# french               - 192
# shoegaze             - 192
# dark ambient         - 190
# dark electro         - 175
# progressive metal    - 172
# emo                  - 170
# ebm                  - 170
# idm                  - 167
# black metal          - 161
# british              - 159
# sad                  - 154
# world                - 150
# death metal          - 150
# hardcore             - 147
# doom metal           - 136
# electro              - 131
# funk                 - 129
# reggae               - 128
# house                - 125
# rap                  - 123
# dream pop            - 123
# guitar               - 116
# synthpop             - 115
# psychedelic rock     - 113
# neofolk              - 111
# happy                - 110
# drum and bass        - 105
# comedy               - 102
# celtic               - 102
# techno               - 98
# easy listening       - 95
# post-hardcore        - 94
# disco                - 93
# dubstep              - 91
# metalcore            - 91
# ska                  - 90
# martial industrial   - 85
# spanish              - 83
# latin                - 83
# psychill             - 81
# meditation           - 80
# avant-garde          - 79
# german               - 78
# swedish              - 73
# britpop              - 73
# thrash metal         - 69
# drone                - 69
# nu jazz              - 68
# lo-fi                - 67
# medieval             - 65
# pop punk             - 62
# r&b                  - 62
# gothic metal         - 61
# gothic rock          - 57
# dub                  - 57
# choral               - 56
# contemporary classical - 55
# stoner rock          - 55
# power metal          - 55
# symphonic metal      - 53
# anime                - 52
# grunge               - 52
# summer               - 51
# j-pop                - 51
# christian rock       - 50
# k-pop                - 49
# deathcore            - 48
# folk rock            - 48
# goth                 - 47
# melodic death metal  - 45
# soft rock            - 44
# post-metal           - 42
# gospel               - 41
# garage rock          - 40
# math rock            - 40
# worship              - 39
# halloween            - 39
# pop rock             - 39
# blues rock           - 38
# nu metal             - 38
# focus                - 37
# mantra               - 37
# mpb                  - 36
# electropop           - 36
# futurepop            - 36
# grindcore            - 36
# noise rock           - 36
# krautrock            - 35
# spoken word          - 34
# industrial metal     - 33
# screamo              - 32
# glam rock            - 32
# electro-industrial   - 31
# renaissance          - 30
# cabaret              - 29
# minimalism           - 29
# glitch               - 29
# dark cabaret         - 29
# acid jazz            - 29
# baroque              - 29
# alternative metal    - 28
# breakcore            - 28
# mathcore             - 27
# j-rock               - 27
# indie folk           - 27
# swing                - 26
# space rock           - 26
# deep house           - 26
# electroclash         - 26
# bossa nova           - 25
# indietronica         - 25
# psychobilly          - 25
# slowcore             - 25
# minimal techno       - 25
# power pop            - 24
# cello                - 23
# trip hop             - 23
# violin               - 22
# art pop              - 21
# piano rock           - 21
# world fusion         - 21
# yoga                 - 21
# technical death metal - 21
# smooth jazz          - 21
# nederpop             - 21
# chanson              - 20
# reggaeton            - 20
# a cappella           - 20
# horror punk          - 20
# video game music     - 20
# bluegrass            - 20
# chillwave            - 20
# comic                - 19
# native american      - 19
# poetry               - 19
# freak folk           - 19
# southern rock        - 18
# indian               - 18
# country rock         - 18
# sufi                 - 18
# rockabilly           - 17
# breakbeat            - 17
# quiet storm          - 16
# hardcore punk        - 16
# ccm                  - 16
# industrial rock      - 16
# visual kei           - 16
# party                - 16
# novelty              - 16
# progressive trance   - 15
# chamber pop          - 15
# rock en espanol      - 15
# art rock             - 14
# goa trance           - 14
# psychedelic trance   - 14
# jazz fusion          - 14
# witch house          - 14
# rhythm and blues     - 14
# aggrotech            - 14
# nerdcore             - 14
# progressive house    - 14
# tango                - 14
# eurovision           - 13
# breaks               - 13
# latin pop            - 13
# darkstep             - 13
# sleep                - 13
# didgeridoo           - 12
# folk metal           - 12
# jam band             - 12
# melodic hardcore     - 12
# cyberpunk            - 12
# deathrock            - 12
# neo soul             - 11
# steampunk            - 11
# beats                - 11
# gypsy                - 11
# turkish              - 11
# free jazz            - 11
# fado                 - 10
# happy hardcore       - 10
# zeuhl                - 10
# harp                 - 10
# stoner metal         - 10
# garage               - 10
# psydub               - 10
# dark folk            - 10
# underground hip hop  - 10
# folktronica          - 10
# parody               - 10
# chiptune             - 10
# liedermacher         - 9
# neo-pagan            - 9
# drama                - 9
# banjo                - 9
# trap                 - 9
# new weird america    - 9
# groove               - 9
# power electronics    - 9
# brazil               - 8
# poezja spiewana      - 8
# tech house           - 8
# experimental rock    - 8
# electro house        - 8
# russian rock         - 8
# riot grrrl           - 8
# dancehall            - 8
# calypso              - 8
# eurodance            - 8
# big beat             - 8
# sludge metal         - 8
# hardstyle            - 8
# uplifting trance     - 8
# dark wave            - 8
# lullaby              - 8
# no wave              - 8
# chill out            - 7
# digital hardcore     - 7
# instrumental rock    - 7
# big band             - 7
# afrobeat             - 7
# flamenco             - 7
# grime                - 7
# kids                 - 7
# groove metal         - 7
# coldwave             - 7
# glam metal           - 7
# dub techno           - 7
# oi                   - 7
# crunk                - 7
# hamburger schule     - 6
# depressive black metal - 6
# 8-bit                - 6
# progressive psytrance - 6
# latin rock           - 6
# minimal synth        - 6
# latino               - 6
# space ambient        - 6
# atmospheric black metal - 6
# neoclassical darkwave - 6
# alternative country  - 6
# qawwali              - 6
# ritual ambient       - 6
# opera                - 6
# bachata              - 6
# sunshine pop         - 6
# broadway             - 6
# jangle pop           - 5
# romance              - 5
# paisley underground  - 5
# mashup               - 5
# neo-classical        - 5
# finnish metal        - 5
# sleaze rock          - 5
# djent                - 5
# healing              - 5
# belly dance          - 5
# contemporary gospel  - 5
# trova                - 5
# ostrock              - 5
# early music          - 5
# zen                  - 5
# christian music      - 5
# melodic black metal  - 5
# hard trance          - 5
# folk punk            - 5
# jazz rock            - 5
# belarusian rock      - 4
# rock nacional        - 4
# vocal jazz           - 4
# ska punk             - 4
# polka                - 4
# avant-garde metal    - 4
# songwriter           - 4
# sitar                - 4
# cartoon              - 4
# ukulele              - 4
# salsa                - 4
# straight edge        - 4
# turntablism          - 4
# duduk                - 4
# oud                  - 4
# kleinkunst           - 4
# freestyle            - 4
# cybergrind           - 4
# symphonic black metal - 4
# indian classical     - 4
# noise pop            - 4
# acid house           - 4
# madchester           - 4
# alternative pop      - 4
# deep ambient         - 4
# brazilian rock       - 4
# vocal trance         - 4
# post-black metal     - 4
# ambient pop          - 4
# underground rap      - 4
# russian alternative  - 4
# skate punk           - 4
# orchestra            - 4
# soundtracks          - 4
# water                - 4
# baroque pop          - 4
# neurofunk            - 4
# psychedelic pop      - 4
# celtic punk          - 3
# industrial black metal - 3
# melodic metal        - 3
# geek rock            - 3
# new rave             - 3
# samba                - 3
# italian pop          - 3
# electronic rock      - 3
# outsider             - 3
# girl group           - 3
# french pop           - 3
# spanish pop          - 3
# anthem               - 3
# garage punk          - 3
# gypsy punk           - 3
# tropical             - 3
# club                 - 3
# jungle               - 3
# post-grunge          - 3
# new jack swing       - 3
# birthday             - 3
# exotica              - 3
# abstract             - 3
# progressive breaks   - 3
# demoscene            - 3
# horrorcore           - 3
# contemporary jazz    - 3
# brutal death metal   - 3
# klezmer              - 3
# atmosphere           - 3
# suomisaundi          - 3
# football             - 3
# dark jazz            - 3
# accordion            - 3
# theme                - 3
# liquid funk          - 3
# rave                 - 3
# dance-punk           - 3
# anti-folk            - 3
# schlager             - 3
# funeral doom         - 3
# children             - 3
# music hall           - 2
# tabla                - 2
# mariachi             - 2
# irish folk           - 2
# taiko                - 2
# classical piano      - 2
# comedy rock          - 2
# industrial techno    - 2
# nwobhm               - 2
# album rock           - 2
# tropicalia           - 2
# german rock          - 2
# bhangra              - 2
# nu disco             - 2
# polish rock          - 2
# washboard            - 2
# death industrial     - 2
# roots reggae         - 2
# synthwave            - 2
# power noise          - 2
# symphonic rock       - 2
# redneck              - 2
# mandolin             - 2
# celtic rock          - 2
# modern rock          - 2
# eurobeat             - 2
# northern soul        - 2
# italian folk         - 2
# hawaiian             - 2
# praise               - 2
# music box            - 2
# smooth soul          - 2
# vaporwave            - 2
# psychedelic folk     - 2
# crust punk           - 2
# japanese folk        - 2
# street punk          - 2
# gothic americana     - 2
# powerviolence        - 2
# contemporary folk    - 2
# bolero               - 2
# circuit              - 2
# new romantic         - 2
# gypsy jazz           - 2
# experimental ambient - 2
# disney               - 2
# delta blues          - 2
# full on              - 2
# dixieland            - 2
# moog                 - 2
# lilith               - 2
# classical guitar     - 2
# mambo                - 2
# cool jazz            - 2
# turkish rock         - 2
# french hip hop       - 2
# west coast rap       - 2
# musica andina        - 2
# chillstep            - 2
# brass band           - 2
# string quartet       - 2
# anarcho-punk         - 2
# motown               - 2
# estonian metal       - 2
# hauntology           - 2
# funk metal           - 2
# environmental        - 2
# szanty               - 1
# d-beat               - 1
# bajki                - 1
# beach music          - 1
# chicano rap          - 1
# turkish pop          - 1
# indie-pop            - 1
# french reggae        - 1
# hard house           - 1
# j-rap                - 1
# jazz piano           - 1
# drill and bass       - 1
# manguebeat           - 1
# tech trance          - 1
# funk rock            - 1
# bhajan               - 1
# black noise          - 1
# vocal house          - 1
# persian traditional  - 1
# pony                 - 1
# hungarian pop        - 1
# progressive deathcore - 1
# progressive post-hardcore - 1
# opm                  - 1
# guqin                - 1
# gamelan              - 1
# darbuka              - 1
# finnish pop          - 1
# pop rap              - 1
# texas country        - 1
# musique concrete     - 1
# art punk             - 1
# highlife             - 1
# brutal deathcore     - 1
# dark disco           - 1
# future garage        - 1
# jazz funk            - 1
# garage rock revival  - 1
# electro jazz         - 1
# soca                 - 1
# rumba                - 1
# spanish classical    - 1
# merengue             - 1
# minecraft            - 1
# merseybeat           - 1
# broken beat          - 1
# houston rap          - 1
# noisecore            - 1
# organic ambient      - 1
# tex-mex              - 1
# emocore              - 1
# murga                - 1
# carnaval             - 1
# orgcore              - 1
# shred                - 1
# chaotic hardcore     - 1
# melodic hard rock    - 1
# fast melodic punk    - 1
# chamber folk         - 1
# deep techno          - 1
# cantautor            - 1
# emo rap              - 1
# brega                - 1
# balearic             - 1
# atmospheric sludge   - 1
# red dirt             - 1
# retro metal          - 1
# kwaito               - 1
# psytech              - 1
# electric blues       - 1
# boogaloo             - 1
# country pop          - 1
# speed metal          - 1
# library music        - 1
# jazz saxophone       - 1
# twee pop             - 1
# flamenco fusion      - 1
# spanish rock         - 1
# light music          - 1
# british folk         - 1
# latin alternative    - 1
# gnawa                - 1
# dirty south rap      - 1
# teen pop             - 1
# melodic rap          - 1
# hip house            - 1
# lds                  - 1
# meme rap             - 1
# reiki                - 1
# drone metal          - 1
# glitch hop           - 1
# symphonic death metal - 1
# funk carioca         - 1
# french rock          - 1
# instrumental post-rock - 1
# greek folk           - 1
# synth punk           - 1
# detroit techno       - 1
# kabarett             - 1
# german hip hop       - 1
# ragtime              - 1
# christian metal      - 1
# experimental folk    - 1
# esperanto            - 1
# queercore            - 1
# marimba              - 1
# nasheed              - 1
# ambient black metal  - 1
# indy indie           - 1
# minimal wave         - 1
# country blues        - 1
# christian dance      - 1
# jumpstyle            - 1
# scottish indie       - 1
# jazztronica          - 1
# folk black metal     - 1
# sophisti-pop         - 1
# persian pop          - 1
# sound effects        - 1
# bitpop               - 1
# illbient             - 1
# rock steady          - 1
# synth-pop            - 1
# throat singing       - 1
# yoik                 - 1
# dance pop            - 1
# drone ambient        - 1
# circus               - 1
# rock in opposition   - 1
# neo-psychedelic      - 1
# goregrind            - 1
# erhu                 - 1
# boogie               - 1
# edm                  - 1
# experimental techno  - 1
# iskelma              - 1
# rock-n-roll          - 1
# final fantasy        - 1
# irish rock           - 1
# shibuya-kei          - 1
# humppa               - 1
# east coast hip hop   - 1
# industrial noise     - 1
# ranchera             - 1
# field recording      - 1
# roots rock           - 1
# hyperpop             - 1
# bells                - 1
# coco                 - 1
# american primitive   - 1
# erotica              - 1
# nintendocore         - 1
# bay area indie       - 1
# cumbia               - 1
# dance rock           - 1
# ngoni                - 1
# experimental electronic - 1
# reading              - 1
# viking metal         - 1
# christian pop        - 1
# progressive black metal - 1
# new-age              - 1
# hard techno          - 1
# free improvisation   - 1
# soukous              - 1
# drone folk           - 1
# drill                - 1
# kirtan               - 1
# acid techno          - 1
# nueva cancion        - 1
# minimal-techno       - 1
# contemporary country - 1
# acid trance          - 1
# harpsichord          - 1
# nightcore            - 1
# raw black metal      - 1
# hands up             - 1
# bubblegum pop        - 1
# pirate               - 1
# outlaw country       - 1
# swamp rock           - 1
# alternative dance    - 1
